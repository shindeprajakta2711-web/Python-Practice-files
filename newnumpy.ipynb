# %%
import numpy as np
numbers = ([10, 20, 30, 40, 50])
print("Array:\n", numbers)
print("Mean: \n", np.mean(numbers))
print("Sum: \n", np.sum(numbers))
print("Max: \n", np.max(numbers))

#Creating the matrix
matrix = ([10, 20, 30],[40, 50, 60])
print("Matrix:\n", matrix)

a = np.arange(1,10)
b = a.reshape(3,3)
print("Reshapedd matrix: \n", b)
